# %% [markdown]
# # import các thư viện cần thiết

# %%
from time import sleep
import requests
from selenium import webdriver
import pickle
import csv
import os
import pandas as pd

# %%
def init_browser():
    # capabilities["loggingPrefs"] = {"performance": "ALL"}  # chromedriver < ~75
    options = webdriver.ChromeOptions()
    # options.add_argument('--headless')
    # options.add_argument('--no-sandbox')
    # options.add_argument('--disable-dev-shm-usage')
    options.add_argument('--user-data-dir=C:/Users/minhk/AppData/Local/Google/Chrome/User Data')
    options.add_argument('--profile-directory=Profile 1')

    options.binary_location = r"C:\Program Files\Google\Chrome\Application\chrome.exe"

    return webdriver.Chrome(executable_path="chromedriver.exe", options=options)

# %%
LOGIN_URL = "https://upwork.com/"

# %%
def write_to_csv(filename, info):
    with open(filename, 'a', encoding="utf-8", newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(info.values())

# %%
session = requests.session()

headers = {
        'sec-ch-ua': '"Chromium";v="93", "\"Not\\A;Brand";v="99"',
        'X-Odesk-User-Agent': 'oDesk LM',
        'sec-ch-ua-mobile': '?0',
        "Authorization": 'Bearer oauth2v2_5764e4c87cd8bdb04624fefe47ca3c4d',
        'accept': 'application/json, text/plain, */*',
        'X-Oauth2-Required': 'True',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.111 Safari/537.36',
        'X-Requested-With': 'XMLHttpRequest',
        "X-Odesk-Csrf-Token": "61408d93fe0f8fa8d9b0ff889de3422a",
        'Sec-Ch-Ua-Platform': 'windows',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'cors',
        'Sec-Fetch-Dest': 'empty',
        'Referer': 'https://www.upwork.com/ab/find-work/recommended',
        'upgrade-insecure-requests': '1',
        'Accept-Encoding': 'gzip, deflate',
        'Accept-Language': 'en-US,en;q=0.9'
    }

session.headers.update(headers)

# %%
def get_profile_details(profile):
    save_profile_to_csv(profile)

# %%
def get_top_skills(top_skills):
    string = ""
    for skill in top_skills:
        string = string +", "+ str(skill['skill']['prettyName'])
    return string[2:]

# %%
def check_key_exists(key, _object):
    if(key in _object):
        return _object[key]
    else:
        return None

# %%
def save_profile_to_csv(profile):
    result = {}
    result['ciphertext']            = profile['ciphertext']
    result['username']              = profile['shortName']
   
    result['title']                 = profile['title']
    result['description']           = profile['description']
   
    result['top_skills']            = get_top_skills(profile['skills'])
    result['country']               = profile['location']['country']
    result['city']                  = profile['location']['city']
    result['state']                 = profile['location']['state']
    result['hourly_rate']           = profile['hourlyRate']['amount']
    result['primary_currency']      = profile['hourlyRate']['currencyCode']
    result['combinedTotalEarnings']      = profile['combinedTotalEarnings']
    result['combinedTotalRevenue']        = profile['combinedTotalRevenue']
    result['totalJobsWorked']       = profile['totalFpJobs']
    result['totalHourlyJobs'] = profile['totalHourlyJobs']
    write_to_csv(filename_supply, result)

# %%
filename_supply = "supply-vn.csv"

if(not os.path.isfile(filename_supply)):
    with open(filename_supply, 'w', encoding="utf-8", newline='') as csvfile:
        fieldnames = ["ciphertext", "username", "title", "description", "top_skills", "country", "city", "state", "hourly_rate", "primary_currency", "combinedTotalEarnings", "combinedTotalRevenue", "totalJobsWorked", "totalHourlyJobs"]
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader() 
        csvfile.close()

# %%
df = pd.read_csv(filename_supply)

def checkExists(data):
    return data in df.ciphertext.values

# %%
for page in range(1, 500):
    response = session.get('https://www.upwork.com/search/profiles/api/search?loc=vietnam&page={}'.format(page))
    profiles = response.json()['profiles']
    for profile in profiles:
        if(checkExists(profile['ciphertext'])):
            continue
        else:
            print(profile['ciphertext'])
            get_profile_details(profile)
# Out:
# ~01519c2a9cb37ae905
# ~01f1c457918940b942
# ~01d1198187badeb489
# ~01b9f0487938dcc2c3
# ~012feae634dfa3fff0
# ~015bfdb6374910f984
# ~0165565a013d3f63ab
# ~015158456e8c13f0f0
# ~01600e5ee8a3bf4634
# ~01bff63c24db666732
# ~0197c050e5e35cf7cc
# ~017e387209dcc5d2ea
# ~01416d9621d1598e03
# ~01b98d4f47326754a3
# ~019bc8efc0b279a31d
# ~0198631759486bf6b5
# ~01fe95b1afaacf52d4
# ~0197da34e5765788e2
# ~01c8b867684fc2b7a8
# ~015f8a173bdfbe90c3
# ~01f4884c1b92244275
# ~01cda7df17d95ba435
# ~0118e4aa80c65ece7e
# ~0135a7bb1e112fe1c4
# ~01a78384dbbe7c08b1
# ~012017f51fa1c4404c
# ~013b52dc16d8f0f73a
# ~01d88c708f997b3c6b
# ~01373a006fc4bb7319
# ~010fb88828eccf60bc
# ~013a744af76ec95bc7
# ~018106bf8ccd722fa5
# ~0139449fedff7afde5
# ~0157e37728f508e09d
# ~0102bfe02ed05bab77
# ~016b512ebed4c1ead7
# ~01691671a62b511483
# ~0100ef7ec0e311a525
# ~017447579316f644e0
# ~013cb1198eac9e48de
# ~01e42d224af0ec9908
# ~01bf13215b5004d1ff
# ~01ea599f137414da5b
# ~01b3b5aeefde8b78a7
# ~017aeaebd584bfddd9
# ~01b44d703b4f443c47
# ~016354e20682f90653
# ~017d532dc01083659e
# ~014584935da43a9600
# ~010311c301225ad0fa
# ~017f5aa0bf987e92eb
# ~0115118344d5e05e11
# ~01e660bd51c729936b
# ~01493a063f1768437b
# ~01b986461611c15f28
# ~016a3383f82922afac
# ~019a59e0b55e26401a
# ~01d7a85b28e1d1c2ef
# ~0138c7487e3ee642bf
# ~011b094c6d38011f6f
# ~0182fe7353b728ab57
# ~01110dc8961e2a71d6
# ~014c3f9ce5586d1e46
# ~010bdfe8c855aa94d8
# ~01cfda64337c61acf2
# ~01b424da6fb2f3e8c4
# ~017bdc5f6726ea08d1
# ~01d5f18d8fda372b27
# ~0148185212084e0e21
# ~0181d9653a5ee1b68c
# ~01475dc7e682d88d5b
# ~01f6e4d45560d256c5
# ~0179f8d46bf709e15b
# ~01862db4a8c2ebc1c1
# ~01491583121b5f1dc6
# ~01d38259f122a7478f
# ~0156917daab2914836
# ~01d8ca88bd0a97e0c3
# ~01b5fadbd2f1df018a
# ~018e74f41ed5654bb6
# ~01ddf976c99f4d0cfb
# ~01810c1c016cad0976
# ~01f90a37fe4820ac5a
# ~012a0380d6d6bdf6b0
# ~01be5d062275828b8f
# ~01e720aafc35dfa3fb
# ~0147998e075e04bea4
# ~0115df0230cbd44055
# ~018521437f8df45c63
# ~01849ef4e5f8ed43fd
# ~019cc02459f7bd55f7
# ~01459212d53ffbd751
# ~010b765cb2252b895c
# ~011c862a4234831a02
# ~019dc2b68ae32768c5
# ~011f0b558a9de4f2e2
# ~0146630406db326a98
# ~011be8be5de506d460
# ~0137c75cabca218cde
# ~01a007298f7edd2282
# ~01a2ad7df8949216bf
# ~012403b39fb8809991
# ~0199cf1c1583369a91
# ~019d4b6f8e94815251
# ~011afa33c15e1e0b40
# ~015af00d88522ba2ec
# ~01a66311930fe261ff
# ~014a147fdba45d8d45
# ~01b2f4d654f174173e
# ~01d17a2cf549627ba1
# ~018ed29022b3f5b7aa
# ~01b43ad528082088b8
# ~01629f784a81b74bcc
# ~01f241e6c94ffcd460
# ~01eeeead87a9516c95
# ~01d7573df728ab32d8
# ~01657cd116603503f8
# ~01096bc996442b6a95
# ~0180babe78c12941d0
# ~01eccb82216fe291c3
# ~01ae48c77f23604ccd
# ~01214f26c83d802171
# ~01ed8131ab31b96bb3
# ~019d91b56d1a70cdbd
# ~019c22e4252873677b
# ~01cdca7ccd8a08a0cc
# ~0114244fdc55bd1a5b
# ~01cab33f47a3e4beaa
# ~010450b27faeed9a78
# ~01481c4bcee183e797
# ~01ab654c32e5d1e96c
# ~0102d59b9f47047034
# ~01f6bd6d3d9d8efd7f
# ~01b4d79c4dacadbf5a
# ~0163e29f85b8e15f38
# ~01b42af45ed7fb0cc6
# ~0136de0f930749dda2
# ~01e5d93d392b2bf287
# ~018a360dd07fcedfb4
# ~01dc267b7a6a26f9ed
# ~0136bc3606f18ca719
# ~017bb4baf44926ef7b
# ~018ed2a32986c8b5e0
# ~016d4dc5f65a5dadc3
# ~01992f3b49a0e7e921
# ~0151e3c1c2149cc1a0
# ~01b2e46e7129894e13
# ~019b572508dcd32844
# ~010f21d3fe302ed8c1
# ~01e9356864234c385b
# ~01378f591c72590f2a
# ~016ee4a4d34f0ceee2
# ~01c6767da938c83145
# ~013bff740d85ab68eb
# ~014652c240e6af7f50
# ~015f988325972d028b
# ~0138eeb6c7ddc4cab8
# ~013652bd3567ccca91
# ~01121bb4e9b9382e6a
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\TRANKH~1\AppData\Local\Temp/ipykernel_3512/3899171252.py in <module>
#       7         else:
#       8             print(profile['ciphertext'])
# ----> 9             get_profile_details(profile)
#      10
#
# C:\Users\TRANKH~1\AppData\Local\Temp/ipykernel_3512/305165588.py in get_profile_details(profile)
#       1 def get_profile_details(profile):
# ----> 2     save_profile_to_csv(profile)
#
# C:\Users\TRANKH~1\AppData\Local\Temp/ipykernel_3512/2635950826.py in save_profile_to_csv(profile)
#       7     result['description']           = profile['description']
#       8
# ----> 9     result['top_skills']            = get_top_skills(profile['skills'])
#      10     result['country']               = profile['location']['country']
#      11     result['city']                  = profile['location']['city']
#
# C:\Users\TRANKH~1\AppData\Local\Temp/ipykernel_3512/679853615.py in get_top_skills(top_skills)
#       1 def get_top_skills(top_skills):
#       2     string = ""
# ----> 3     for skill in top_skills:
#       4         string = string +", "+ str(skill['skill']['prettyName'])
#       5     return string[2:]
#
# TypeError: 'NoneType' object is not iterable
